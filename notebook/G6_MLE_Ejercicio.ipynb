# %%
#Pycaret:
#from pycaret.regression import *

#Pipeline de pycaret:

#1. Setup() : Definir el dataset y parametros
    #exp = setup(data=df, target='precio', session_id=12,normalize=True)
#2. Compare_models(): Compara multiples modelos y los rankea
    #mejor_modelo = compare_models()

#3. Create model() : Crea un modelo especifico
    #lr = create_model('lr') 

#4. Tune_model() :Ajuste automatico de hiperparametros
    #tuned_lr = tune_model(lr)

#5. plot_model(): visualiza (graficamente) el desempeño del modelo
    #plot_model(tuned_lr,plot='residuals')
    #plot_model(tuned_lr,plot='feature')

#6. evaluate_model(): UI de evaluación del modelo
    #evaluate_model(tuned_lr)

#7. predict_model(): Predicciones sobre nuevos datos en el DF
    #predicciones = predict_model(tuned_lr,data=nuevo_df)

#8. save_model()/load_model(): Guardar y cargar modelo.
    #save_model(tunel_lr,'modelo_final')

# %%
#Caso : Predicción de precios de departamentos en Lima:
#Objetivo: Construir un modelo de regresión automatica con pycaret para predecir el precio de departamentos
#en base a sus caracteristicas.

# %%
import pandas as pd
from pycaret.regression import *

# %%
#1. Cargamos la data:
df = pd.read_csv('precio_departamentos.csv')

# %%
df.head()
# Out:
#    area_m2  num_habitaciones  num_banos    distrito  antiguedad_anos  \
# 0      139                 1          2  San Isidro                7
# 1       96                 1          1  San Isidro                7
# 2      122                 4          1  San Isidro               23
# 3      128                 2          1       Surco               21
# 4      132                 3          2       Surco               19
#
#    vista_mar     precio
# 0          0  380619.28
# 1          0  221302.53
# 2          0  338702.68
# 3          1  341815.62
# 4          0  346460.60

# %%
#Inicializar el experimiento
reg  = setup(data=df,target='precio',session_id=123,normalize=True,categorical_features=['distrito'])
# Out:
# <style type="text/css">
# #T_c3675_row9_col1, #T_c3675_row15_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_c3675">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_c3675_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_c3675_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c3675_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_c3675_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_c3675_row0_col1" class="data row0 col1" >123</td>
#     </tr>
#     <tr>
#       <th id="T_c3675_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_c3675_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_c3675_row1_col1" class="data row1 col1" >precio</td>
#     </tr>
#     <tr>
#       <th id="T_c3675_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_c3675_row2_col0" class="data row2 col0" >Target type</td>
#       <td id="T_c3675_row2_col1" class="data row2 col1" >Regression</td>
#     </tr>
#     <tr>
#       <th id="T_c3675_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_c3675_row3_col0" class="data row3 col0" >Original data shape</td>
#       <td id="T_c3675_row3_col1" class="data row3 col1" >(100, 7)</td>
#     </tr>
#     <tr>
#       <th id="T_c3675_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_c3675_row4_col0" class="data row4 col0" >Transformed data shape</td>
#       <td id="T_c3675_row4_col1" class="data row4 col1" >(100, 10)</td>
#     </tr>
#     <tr>
#       <th id="T_c3675_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_c3675_row5_col0" class="data row5 col0" >Transformed train set shape</td>
#       <td id="T_c3675_row5_col1" class="data row5 col1" >(70, 10)</td>
#     </tr>
#     <tr>
#       <th id="T_c3675_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_c3675_row6_col0" class="data row6 col0" >Transformed test set shape</td>
#       <td id="T_c3675_row6_col1" class="data row6 col1" >(30, 10)</td>
#     </tr>
#     <tr>
#       <th id="T_c3675_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_c3675_row7_col0" class="data row7 col0" >Numeric features</td>
#       <td id="T_c3675_row7_col1" class="data row7 col1" >5</td>
#     </tr>
#     <tr>
#       <th id="T_c3675_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_c3675_row8_col0" class="data row8 col0" >Categorical features</td>
#       <td id="T_c3675_row8_col1" class="data row8 col1" >1</td>
#     </tr>
#     <tr>
#       <th id="T_c3675_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_c3675_row9_col0" class="data row9 col0" >Preprocess</td>
#       <td id="T_c3675_row9_col1" class="data row9 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_c3675_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_c3675_row10_col0" class="data row10 col0" >Imputation type</td>
#       <td id="T_c3675_row10_col1" class="data row10 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_c3675_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_c3675_row11_col0" class="data row11 col0" >Numeric imputation</td>
#       <td id="T_c3675_row11_col1" class="data row11 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_c3675_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_c3675_row12_col0" class="data row12 col0" >Categorical imputation</td>
#       <td id="T_c3675_row12_col1" class="data row12 col1" >mode</td>
#     </tr>
#     <tr>
#       <th id="T_c3675_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_c3675_row13_col0" class="data row13 col0" >Maximum one-hot encoding</td>
#       <td id="T_c3675_row13_col1" class="data row13 col1" >25</td>
#     </tr>
#     <tr>
#       <th id="T_c3675_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_c3675_row14_col0" class="data row14 col0" >Encoding method</td>
#       <td id="T_c3675_row14_col1" class="data row14 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_c3675_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_c3675_row15_col0" class="data row15 col0" >Normalize</td>
#       <td id="T_c3675_row15_col1" class="data row15 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_c3675_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_c3675_row16_col0" class="data row16 col0" >Normalize method</td>
#       <td id="T_c3675_row16_col1" class="data row16 col1" >zscore</td>
#     </tr>
#     <tr>
#       <th id="T_c3675_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_c3675_row17_col0" class="data row17 col0" >Fold Generator</td>
#       <td id="T_c3675_row17_col1" class="data row17 col1" >KFold</td>
#     </tr>
#     <tr>
#       <th id="T_c3675_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_c3675_row18_col0" class="data row18 col0" >Fold Number</td>
#       <td id="T_c3675_row18_col1" class="data row18 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_c3675_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_c3675_row19_col0" class="data row19 col0" >CPU Jobs</td>
#       <td id="T_c3675_row19_col1" class="data row19 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_c3675_level0_row20" class="row_heading level0 row20" >20</th>
#       <td id="T_c3675_row20_col0" class="data row20 col0" >Use GPU</td>
#       <td id="T_c3675_row20_col1" class="data row20 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_c3675_level0_row21" class="row_heading level0 row21" >21</th>
#       <td id="T_c3675_row21_col0" class="data row21 col0" >Log Experiment</td>
#       <td id="T_c3675_row21_col1" class="data row21 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_c3675_level0_row22" class="row_heading level0 row22" >22</th>
#       <td id="T_c3675_row22_col0" class="data row22 col0" >Experiment Name</td>
#       <td id="T_c3675_row22_col1" class="data row22 col1" >reg-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_c3675_level0_row23" class="row_heading level0 row23" >23</th>
#       <td id="T_c3675_row23_col0" class="data row23 col0" >USI</td>
#       <td id="T_c3675_row23_col1" class="data row23 col1" >65c1</td>
#     </tr>
#   </tbody>
# </table>

# %%
#3. Comparar modelos automaticamente:
best_model = compare_models()
# Out:
# <style type="text/css">
# #T_da13a th {
#   text-align: left;
# }
# #T_da13a_row0_col0, #T_da13a_row0_col2, #T_da13a_row0_col3, #T_da13a_row0_col5, #T_da13a_row1_col0, #T_da13a_row1_col1, #T_da13a_row1_col2, #T_da13a_row1_col3, #T_da13a_row1_col5, #T_da13a_row2_col0, #T_da13a_row2_col2, #T_da13a_row2_col3, #T_da13a_row2_col5, #T_da13a_row3_col0, #T_da13a_row3_col1, #T_da13a_row3_col5, #T_da13a_row4_col0, #T_da13a_row4_col1, #T_da13a_row4_col2, #T_da13a_row4_col3, #T_da13a_row4_col4, #T_da13a_row4_col6, #T_da13a_row5_col0, #T_da13a_row5_col1, #T_da13a_row5_col2, #T_da13a_row5_col3, #T_da13a_row5_col4, #T_da13a_row5_col5, #T_da13a_row5_col6, #T_da13a_row6_col0, #T_da13a_row6_col1, #T_da13a_row6_col2, #T_da13a_row6_col3, #T_da13a_row6_col4, #T_da13a_row6_col5, #T_da13a_row6_col6, #T_da13a_row7_col0, #T_da13a_row7_col1, #T_da13a_row7_col2, #T_da13a_row7_col3, #T_da13a_row7_col4, #T_da13a_row7_col5, #T_da13a_row7_col6, #T_da13a_row8_col0, #T_da13a_row8_col1, #T_da13a_row8_col2, #T_da13a_row8_col3, #T_da13a_row8_col4, #T_da13a_row8_col5, #T_da13a_row8_col6, #T_da13a_row9_col0, #T_da13a_row9_col1, #T_da13a_row9_col2, #T_da13a_row9_col3, #T_da13a_row9_col4, #T_da13a_row9_col5, #T_da13a_row9_col6, #T_da13a_row10_col0, #T_da13a_row10_col1, #T_da13a_row10_col2, #T_da13a_row10_col3, #T_da13a_row10_col4, #T_da13a_row10_col5, #T_da13a_row10_col6, #T_da13a_row11_col0, #T_da13a_row11_col1, #T_da13a_row11_col2, #T_da13a_row11_col3, #T_da13a_row11_col4, #T_da13a_row11_col5, #T_da13a_row11_col6, #T_da13a_row12_col0, #T_da13a_row12_col1, #T_da13a_row12_col2, #T_da13a_row12_col3, #T_da13a_row12_col4, #T_da13a_row12_col5, #T_da13a_row12_col6, #T_da13a_row13_col0, #T_da13a_row13_col1, #T_da13a_row13_col2, #T_da13a_row13_col3, #T_da13a_row13_col4, #T_da13a_row13_col5, #T_da13a_row13_col6, #T_da13a_row14_col0, #T_da13a_row14_col1, #T_da13a_row14_col2, #T_da13a_row14_col3, #T_da13a_row14_col4, #T_da13a_row14_col5, #T_da13a_row14_col6, #T_da13a_row15_col0, #T_da13a_row15_col1, #T_da13a_row15_col2, #T_da13a_row15_col3, #T_da13a_row15_col4, #T_da13a_row15_col5, #T_da13a_row15_col6, #T_da13a_row16_col0, #T_da13a_row16_col1, #T_da13a_row16_col2, #T_da13a_row16_col3, #T_da13a_row16_col4, #T_da13a_row16_col5, #T_da13a_row16_col6, #T_da13a_row17_col0, #T_da13a_row17_col1, #T_da13a_row17_col2, #T_da13a_row17_col3, #T_da13a_row17_col4, #T_da13a_row17_col5, #T_da13a_row17_col6 {
#   text-align: left;
# }
# #T_da13a_row0_col1, #T_da13a_row0_col4, #T_da13a_row0_col6, #T_da13a_row1_col4, #T_da13a_row1_col6, #T_da13a_row2_col1, #T_da13a_row2_col4, #T_da13a_row2_col6, #T_da13a_row3_col2, #T_da13a_row3_col3, #T_da13a_row3_col4, #T_da13a_row3_col6, #T_da13a_row4_col5 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_da13a_row0_col7, #T_da13a_row1_col7, #T_da13a_row2_col7, #T_da13a_row3_col7, #T_da13a_row4_col7, #T_da13a_row5_col7, #T_da13a_row6_col7, #T_da13a_row7_col7, #T_da13a_row8_col7, #T_da13a_row9_col7, #T_da13a_row11_col7, #T_da13a_row12_col7, #T_da13a_row13_col7, #T_da13a_row14_col7, #T_da13a_row15_col7, #T_da13a_row16_col7, #T_da13a_row17_col7 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_da13a_row10_col7 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_da13a">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_da13a_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_da13a_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_da13a_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_da13a_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_da13a_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_da13a_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_da13a_level0_col6" class="col_heading level0 col6" >MAPE</th>
#       <th id="T_da13a_level0_col7" class="col_heading level0 col7" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_da13a_level0_row0" class="row_heading level0 row0" >lr</th>
#       <td id="T_da13a_row0_col0" class="data row0 col0" >Linear Regression</td>
#       <td id="T_da13a_row0_col1" class="data row0 col1" >11280.0105</td>
#       <td id="T_da13a_row0_col2" class="data row0 col2" >216055877.4185</td>
#       <td id="T_da13a_row0_col3" class="data row0 col3" >14454.6787</td>
#       <td id="T_da13a_row0_col4" class="data row0 col4" >0.9592</td>
#       <td id="T_da13a_row0_col5" class="data row0 col5" >0.0583</td>
#       <td id="T_da13a_row0_col6" class="data row0 col6" >0.0449</td>
#       <td id="T_da13a_row0_col7" class="data row0 col7" >0.1750</td>
#     </tr>
#     <tr>
#       <th id="T_da13a_level0_row1" class="row_heading level0 row1" >lasso</th>
#       <td id="T_da13a_row1_col0" class="data row1 col0" >Lasso Regression</td>
#       <td id="T_da13a_row1_col1" class="data row1 col1" >11280.1557</td>
#       <td id="T_da13a_row1_col2" class="data row1 col2" >216043061.6317</td>
#       <td id="T_da13a_row1_col3" class="data row1 col3" >14454.2273</td>
#       <td id="T_da13a_row1_col4" class="data row1 col4" >0.9592</td>
#       <td id="T_da13a_row1_col5" class="data row1 col5" >0.0583</td>
#       <td id="T_da13a_row1_col6" class="data row1 col6" >0.0449</td>
#       <td id="T_da13a_row1_col7" class="data row1 col7" >0.1360</td>
#     </tr>
#     <tr>
#       <th id="T_da13a_level0_row2" class="row_heading level0 row2" >lar</th>
#       <td id="T_da13a_row2_col0" class="data row2 col0" >Least Angle Regression</td>
#       <td id="T_da13a_row2_col1" class="data row2 col1" >11280.0105</td>
#       <td id="T_da13a_row2_col2" class="data row2 col2" >216055877.4185</td>
#       <td id="T_da13a_row2_col3" class="data row2 col3" >14454.6787</td>
#       <td id="T_da13a_row2_col4" class="data row2 col4" >0.9592</td>
#       <td id="T_da13a_row2_col5" class="data row2 col5" >0.0583</td>
#       <td id="T_da13a_row2_col6" class="data row2 col6" >0.0449</td>
#       <td id="T_da13a_row2_col7" class="data row2 col7" >0.0040</td>
#     </tr>
#     <tr>
#       <th id="T_da13a_level0_row3" class="row_heading level0 row3" >llar</th>
#       <td id="T_da13a_row3_col0" class="data row3 col0" >Lasso Least Angle Regression</td>
#       <td id="T_da13a_row3_col1" class="data row3 col1" >11280.1667</td>
#       <td id="T_da13a_row3_col2" class="data row3 col2" >216041830.3268</td>
#       <td id="T_da13a_row3_col3" class="data row3 col3" >14454.1746</td>
#       <td id="T_da13a_row3_col4" class="data row3 col4" >0.9592</td>
#       <td id="T_da13a_row3_col5" class="data row3 col5" >0.0583</td>
#       <td id="T_da13a_row3_col6" class="data row3 col6" >0.0449</td>
#       <td id="T_da13a_row3_col7" class="data row3 col7" >0.0040</td>
#     </tr>
#     <tr>
#       <th id="T_da13a_level0_row4" class="row_heading level0 row4" >ridge</th>
#       <td id="T_da13a_row4_col0" class="data row4 col0" >Ridge Regression</td>
#       <td id="T_da13a_row4_col1" class="data row4 col1" >11566.6268</td>
#       <td id="T_da13a_row4_col2" class="data row4 col2" >216281347.5003</td>
#       <td id="T_da13a_row4_col3" class="data row4 col3" >14482.7539</td>
#       <td id="T_da13a_row4_col4" class="data row4 col4" >0.9587</td>
#       <td id="T_da13a_row4_col5" class="data row4 col5" >0.0582</td>
#       <td id="T_da13a_row4_col6" class="data row4 col6" >0.0463</td>
#       <td id="T_da13a_row4_col7" class="data row4 col7" >0.1360</td>
#     </tr>
#     <tr>
#       <th id="T_da13a_level0_row5" class="row_heading level0 row5" >huber</th>
#       <td id="T_da13a_row5_col0" class="data row5 col0" >Huber Regressor</td>
#       <td id="T_da13a_row5_col1" class="data row5 col1" >11821.9848</td>
#       <td id="T_da13a_row5_col2" class="data row5 col2" >221718852.3957</td>
#       <td id="T_da13a_row5_col3" class="data row5 col3" >14657.2633</td>
#       <td id="T_da13a_row5_col4" class="data row5 col4" >0.9578</td>
#       <td id="T_da13a_row5_col5" class="data row5 col5" >0.0588</td>
#       <td id="T_da13a_row5_col6" class="data row5 col6" >0.0479</td>
#       <td id="T_da13a_row5_col7" class="data ro

# %%
lr = create_model('lr')
# Out:
# <style type="text/css">
# #T_34ec4_row10_col0, #T_34ec4_row10_col1, #T_34ec4_row10_col2, #T_34ec4_row10_col3, #T_34ec4_row10_col4, #T_34ec4_row10_col5 {
#   background: yellow;
# }
# </style>
# <table id="T_34ec4">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_34ec4_level0_col0" class="col_heading level0 col0" >MAE</th>
#       <th id="T_34ec4_level0_col1" class="col_heading level0 col1" >MSE</th>
#       <th id="T_34ec4_level0_col2" class="col_heading level0 col2" >RMSE</th>
#       <th id="T_34ec4_level0_col3" class="col_heading level0 col3" >R2</th>
#       <th id="T_34ec4_level0_col4" class="col_heading level0 col4" >RMSLE</th>
#       <th id="T_34ec4_level0_col5" class="col_heading level0 col5" >MAPE</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_34ec4_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_34ec4_row0_col0" class="data row0 col0" >8228.1193</td>
#       <td id="T_34ec4_row0_col1" class="data row0 col1" >128207335.1395</td>
#       <td id="T_34ec4_row0_col2" class="data row0 col2" >11322.8678</td>
#       <td id="T_34ec4_row0_col3" class="data row0 col3" >0.9802</td>
#       <td id="T_34ec4_row0_col4" class="data row0 col4" >0.0408</td>
#       <td id="T_34ec4_row0_col5" class="data row0 col5" >0.0314</td>
#     </tr>
#     <tr>
#       <th id="T_34ec4_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_34ec4_row1_col0" class="data row1 col0" >12369.9967</td>
#       <td id="T_34ec4_row1_col1" class="data row1 col1" >237708701.2564</td>
#       <td id="T_34ec4_row1_col2" class="data row1 col2" >15417.8047</td>
#       <td id="T_34ec4_row1_col3" class="data row1 col3" >0.9735</td>
#       <td id="T_34ec4_row1_col4" class="data row1 col4" >0.0802</td>
#       <td id="T_34ec4_row1_col5" class="data row1 col5" >0.0620</td>
#     </tr>
#     <tr>
#       <th id="T_34ec4_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_34ec4_row2_col0" class="data row2 col0" >11402.7735</td>
#       <td id="T_34ec4_row2_col1" class="data row2 col1" >178327899.8759</td>
#       <td id="T_34ec4_row2_col2" class="data row2 col2" >13353.9470</td>
#       <td id="T_34ec4_row2_col3" class="data row2 col3" >0.9274</td>
#       <td id="T_34ec4_row2_col4" class="data row2 col4" >0.0491</td>
#       <td id="T_34ec4_row2_col5" class="data row2 col5" >0.0403</td>
#     </tr>
#     <tr>
#       <th id="T_34ec4_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_34ec4_row3_col0" class="data row3 col0" >14086.9562</td>
#       <td id="T_34ec4_row3_col1" class="data row3 col1" >375781739.9028</td>
#       <td id="T_34ec4_row3_col2" class="data row3 col2" >19385.0907</td>
#       <td id="T_34ec4_row3_col3" class="data row3 col3" >0.9333</td>
#       <td id="T_34ec4_row3_col4" class="data row3 col4" >0.0633</td>
#       <td id="T_34ec4_row3_col5" class="data row3 col5" >0.0466</td>
#     </tr>
#     <tr>
#       <th id="T_34ec4_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_34ec4_row4_col0" class="data row4 col0" >9469.3045</td>
#       <td id="T_34ec4_row4_col1" class="data row4 col1" >146238973.8241</td>
#       <td id="T_34ec4_row4_col2" class="data row4 col2" >12092.9307</td>
#       <td id="T_34ec4_row4_col3" class="data row4 col3" >0.9816</td>
#       <td id="T_34ec4_row4_col4" class="data row4 col4" >0.0354</td>
#       <td id="T_34ec4_row4_col5" class="data row4 col5" >0.0299</td>
#     </tr>
#     <tr>
#       <th id="T_34ec4_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_34ec4_row5_col0" class="data row5 col0" >10738.6190</td>
#       <td id="T_34ec4_row5_col1" class="data row5 col1" >222111756.4850</td>
#       <td id="T_34ec4_row5_col2" class="data row5 col2" >14903.4143</td>
#       <td id="T_34ec4_row5_col3" class="data row5 col3" >0.9663</td>
#       <td id="T_34ec4_row5_col4" class="data row5 col4" >0.0422</td>
#       <td id="T_34ec4_row5_col5" class="data row5 col5" >0.0336</td>
#     </tr>
#     <tr>
#       <th id="T_34ec4_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_34ec4_row6_col0" class="data row6 col0" >15475.3250</td>
#       <td id="T_34ec4_row6_col1" class="data row6 col1" >330392051.7883</td>
#       <td id="T_34ec4_row6_col2" class="data row6 col2" >18176.6898</td>
#       <td id="T_34ec4_row6_col3" class="data row6 col3" >0.9675</td>
#       <td id="T_34ec4_row6_col4" class="data row6 col4" >0.1052</td>
#       <td id="T_34ec4_row6_col5" class="data row6 col5" >0.0765</td>
#     </tr>
#     <tr>
#       <th id="T_34ec4_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_34ec4_row7_col0" class="data row7 col0" >13786.7347</td>
#       <td id="T_34ec4_row7_col1" class="data row7 col1" >249341965.8060</td>
#       <td id="T_34ec4_row7_col2" class="data row7 col2" >15790.5657</td>
#       <td id="T_34ec4_row7_col3" class="data row7 col3" >0.9295</td>
#       <td id="T_34ec4_row7_col4" class="data row7 col4" >0.0524</td>
#       <td id="T_34ec4_row7_col5" class="data row7 col5" >0.0450</td>
#     </tr>
#     <tr>
#       <th id="T_34ec4_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_34ec4_row8_col0" class="data row8 col0" >8076.4682</td>
#       <td id="T_34ec4_row8_col1" class="data row8 col1" >122365620.4205</td>
#       <td id="T_34ec4_row8_col2" class="data row8 col2" >11061.8995</td>
#       <td id="T_34ec4_row8_col3" class="data row8 col3" >0.9793</td>
#       <td id="T_34ec4_row8_col4" class="data row8 col4" >0.0422</td>
#       <td id="T_34ec4_row8_col5" class="data row8 col5" >0.0318</td>
#     </tr>
#     <tr>
#       <th id="T_34ec4_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_34ec4_row9_col0" class="data row9 col0" >9165.8077</td>
#       <td id="T_34ec4_row9_col1" class="data row9 col1" >170082729.6869</td>
#       <td id="T_34ec4_row9_col2" class="data row9 col2" >13041.5770</td>
#       <td id="T_34ec4_row9_col3" class="data row9 col3" >0.9535</td>
#       <td id="T_34ec4_row9_col4" class="data row9 col4" >0.0720</td>
#       <td id="T_34ec4_row9_col5" class="data row9 col5" >0.0514</td>
#     </tr>
#     <tr>
#       <th id="T_34ec4_level0_row10" class="row_heading level0 row10" >Mean</th>
#       <td id="T_34ec4_row10_col0" class="data row10 col0" >11280.0105</td>
#       <td id="T_34ec4_row10_col1" class="data row10 col1" >216055877.4185</td>
#       <td id="T_34ec4_row10_col2" class="data row10 col2" >14454.6787</td>
#       <td id="T_34ec4_row10_col3" class="data row10 col3" >0.9592</td>
#       <td id="T_34ec4_row10_col4" class="data row10 col4" >0.0583</td>
#       <td id="T_34ec4_row10_col5" class="data row10 col5" >0.0449</td>
#     </tr>
#     <tr>
#       <th id="T_34ec4_level0_row11" class="row_heading level0 row11" >Std</th>
#       <td id="T_34ec4_row11_col0" class="data row11 col0" >2461.3970</td>
#       <td id="T_34ec4_row11_col1" class="data row11 col1" >80687765.6858</td>
#       <td id="T_34ec4_row11_col2" class="data row11 col2" >2667.9844</td>
#       <td id="T_34ec4_row11_col3" class="data row11 col3" >0.0207</td>
#       <td id="T_34ec4_row11_col4" class="data row11 col4" >0.0209</td>
#       <td id="T_34ec4_row11_col5" class="data row11 col5" >0.0144</td>
#     </tr>
#   </tbody>
# </table>

# %%
#5.Ajustar el modelo
tuned_lr = tune_model(lr)
# Out:
# <style type="text/css">
# #T_97dd3_row10_col0, #T_97dd3_row10_col1, #T_97dd3_row10_col2, #T_97dd3_row10_col3, #T_97dd3_row10_col4, #T_97dd3_row10_col5 {
#   background: yellow;
# }
# </style>
# <table id="T_97dd3">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_97dd3_level0_col0" class="col_heading level0 col0" >MAE</th>
#       <th id="T_97dd3_level0_col1" class="col_heading level0 col1" >MSE</th>
#       <th id="T_97dd3_level0_col2" class="col_heading level0 col2" >RMSE</th>
#       <th id="T_97dd3_level0_col3" class="col_heading level0 col3" >R2</th>
#       <th id="T_97dd3_level0_col4" class="col_heading level0 col4" >RMSLE</th>
#       <th id="T_97dd3_level0_col5" class="col_heading level0 col5" >MAPE</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_97dd3_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_97dd3_row0_col0" class="data row0 col0" >8228.1193</td>
#       <td id="T_97dd3_row0_col1" class="data row0 col1" >128207335.1395</td>
#       <td id="T_97dd3_row0_col2" class="data row0 col2" >11322.8678</td>
#       <td id="T_97dd3_row0_col3" class="data row0 col3" >0.9802</td>
#       <td id="T_97dd3_row0_col4" class="data row0 col4" >0.0408</td>
#       <td id="T_97dd3_row0_col5" class="data row0 col5" >0.0314</td>
#     </tr>
#     <tr>
#       <th id="T_97dd3_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_97dd3_row1_col0" class="data row1 col0" >12369.9967</td>
#       <td id="T_97dd3_row1_col1" class="data row1 col1" >237708701.2564</td>
#       <td id="T_97dd3_row1_col2" class="data row1 col2" >15417.8047</td>
#       <td id="T_97dd3_row1_col3" class="data row1 col3" >0.9735</td>
#       <td id="T_97dd3_row1_col4" class="data row1 col4" >0.0802</td>
#       <td id="T_97dd3_row1_col5" class="data row1 col5" >0.0620</td>
#     </tr>
#     <tr>
#       <th id="T_97dd3_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_97dd3_row2_col0" class="data row2 col0" >11402.7735</td>
#       <td id="T_97dd3_row2_col1" class="data row2 col1" >178327899.8759</td>
#       <td id="T_97dd3_row2_col2" class="data row2 col2" >13353.9470</td>
#       <td id="T_97dd3_row2_col3" class="data row2 col3" >0.9274</td>
#       <td id="T_97dd3_row2_col4" class="data row2 col4" >0.0491</td>
#       <td id="T_97dd3_row2_col5" class="data row2 col5" >0.0403</td>
#     </tr>
#     <tr>
#       <th id="T_97dd3_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_97dd3_row3_col0" class="data row3 col0" >14086.9562</td>
#       <td id="T_97dd3_row3_col1" class="data row3 col1" >375781739.9028</td>
#       <td id="T_97dd3_row3_col2" class="data row3 col2" >19385.0907</td>
#       <td id="T_97dd3_row3_col3" class="data row3 col3" >0.9333</td>
#       <td id="T_97dd3_row3_col4" class="data row3 col4" >0.0633</td>
#       <td id="T_97dd3_row3_col5" class="data row3 col5" >0.0466</td>
#     </tr>
#     <tr>
#       <th id="T_97dd3_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_97dd3_row4_col0" class="data row4 col0" >9469.3045</td>
#       <td id="T_97dd3_row4_col1" class="data row4 col1" >146238973.8241</td>
#       <td id="T_97dd3_row4_col2" class="data row4 col2" >12092.9307</td>
#       <td id="T_97dd3_row4_col3" class="data row4 col3" >0.9816</td>
#       <td id="T_97dd3_row4_col4" class="data row4 col4" >0.0354</td>
#       <td id="T_97dd3_row4_col5" class="data row4 col5" >0.0299</td>
#     </tr>
#     <tr>
#       <th id="T_97dd3_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_97dd3_row5_col0" class="data row5 col0" >10738.6190</td>
#       <td id="T_97dd3_row5_col1" class="data row5 col1" >222111756.4850</td>
#       <td id="T_97dd3_row5_col2" class="data row5 col2" >14903.4143</td>
#       <td id="T_97dd3_row5_col3" class="data row5 col3" >0.9663</td>
#       <td id="T_97dd3_row5_col4" class="data row5 col4" >0.0422</td>
#       <td id="T_97dd3_row5_col5" class="data row5 col5" >0.0336</td>
#     </tr>
#     <tr>
#       <th id="T_97dd3_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_97dd3_row6_col0" class="data row6 col0" >15475.3250</td>
#       <td id="T_97dd3_row6_col1" class="data row6 col1" >330392051.7883</td>
#       <td id="T_97dd3_row6_col2" class="data row6 col2" >18176.6898</td>
#       <td id="T_97dd3_row6_col3" class="data row6 col3" >0.9675</td>
#       <td id="T_97dd3_row6_col4" class="data row6 col4" >0.1052</td>
#       <td id="T_97dd3_row6_col5" class="data row6 col5" >0.0765</td>
#     </tr>
#     <tr>
#       <th id="T_97dd3_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_97dd3_row7_col0" class="data row7 col0" >13786.7347</td>
#       <td id="T_97dd3_row7_col1" class="data row7 col1" >249341965.8060</td>
#       <td id="T_97dd3_row7_col2" class="data row7 col2" >15790.5657</td>
#       <td id="T_97dd3_row7_col3" class="data row7 col3" >0.9295</td>
#       <td id="T_97dd3_row7_col4" class="data row7 col4" >0.0524</td>
#       <td id="T_97dd3_row7_col5" class="data row7 col5" >0.0450</td>
#     </tr>
#     <tr>
#       <th id="T_97dd3_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_97dd3_row8_col0" class="data row8 col0" >8076.4682</td>
#       <td id="T_97dd3_row8_col1" class="data row8 col1" >122365620.4205</td>
#       <td id="T_97dd3_row8_col2" class="data row8 col2" >11061.8995</td>
#       <td id="T_97dd3_row8_col3" class="data row8 col3" >0.9793</td>
#       <td id="T_97dd3_row8_col4" class="data row8 col4" >0.0422</td>
#       <td id="T_97dd3_row8_col5" class="data row8 col5" >0.0318</td>
#     </tr>
#     <tr>
#       <th id="T_97dd3_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_97dd3_row9_col0" class="data row9 col0" >9165.8077</td>
#       <td id="T_97dd3_row9_col1" class="data row9 col1" >170082729.6869</td>
#       <td id="T_97dd3_row9_col2" class="data row9 col2" >13041.5770</td>
#       <td id="T_97dd3_row9_col3" class="data row9 col3" >0.9535</td>
#       <td id="T_97dd3_row9_col4" class="data row9 col4" >0.0720</td>
#       <td id="T_97dd3_row9_col5" class="data row9 col5" >0.0514</td>
#     </tr>
#     <tr>
#       <th id="T_97dd3_level0_row10" class="row_heading level0 row10" >Mean</th>
#       <td id="T_97dd3_row10_col0" class="data row10 col0" >11280.0105</td>
#       <td id="T_97dd3_row10_col1" class="data row10 col1" >216055877.4185</td>
#       <td id="T_97dd3_row10_col2" class="data row10 col2" >14454.6787</td>
#       <td id="T_97dd3_row10_col3" class="data row10 col3" >0.9592</td>
#       <td id="T_97dd3_row10_col4" class="data row10 col4" >0.0583</td>
#       <td id="T_97dd3_row10_col5" class="data row10 col5" >0.0449</td>
#     </tr>
#     <tr>
#       <th id="T_97dd3_level0_row11" class="row_heading level0 row11" >Std</th>
#       <td id="T_97dd3_row11_col0" class="data row11 col0" >2461.3970</td>
#       <td id="T_97dd3_row11_col1" class="data row11 col1" >80687765.6858</td>
#       <td id="T_97dd3_row11_col2" class="data row11 col2" >2667.9844</td>
#       <td id="T_97dd3_row11_col3" class="data row11 col3" >0.0207</td>
#       <td id="T_97dd3_row11_col4" class="data row11 col4" >0.0209</td>
#       <td id="T_97dd3_row11_col5" class="data row11 col5" >0.0144</td>
#     </tr>
#   </tbody>
# </table>
# Fitting 10 folds for each of 2 candidates, totalling 20 fits
# Original model was better than the tuned model, hence it will be returned. NOTE: The display metrics are for the tuned model (not the original one).

# %%
#6. Evaluar visualmente
evaluate_model(tuned_lr)
# Out:
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Pipeline Plot', 'pipelin…

# %%
#predicción:
preds= predict_model(tuned_lr)
print(preds.head())
# Out:
# <style type="text/css">
# </style>
# <table id="T_56a92">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_56a92_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_56a92_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_56a92_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_56a92_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_56a92_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_56a92_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_56a92_level0_col6" class="col_heading level0 col6" >MAPE</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_56a92_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_56a92_row0_col0" class="data row0 col0" >Linear Regression</td>
#       <td id="T_56a92_row0_col1" class="data row0 col1" >12666.9295</td>
#       <td id="T_56a92_row0_col2" class="data row0 col2" >222599218.6786</td>
#       <td id="T_56a92_row0_col3" class="data row0 col3" >14919.7593</td>
#       <td id="T_56a92_row0_col4" class="data row0 col4" >0.9743</td>
#       <td id="T_56a92_row0_col5" class="data row0 col5" >0.0807</td>
#       <td id="T_56a92_row0_col6" class="data row0 col6" >0.0576</td>
#     </tr>
#   </tbody>
# </table>
#     area_m2  num_habitaciones  num_banos    distrito  antiguedad_anos  \
# 8        87                 2          2  San Isidro               19
# 70      100                 4          2  Miraflores                5
# 82       31                 1          1       Surco               14
# 28       97                 3          2       Surco               12
# 63      130                 1          1       Surco                0
#
#     vista_mar         precio  prediction_label
# 8           0  242334.515625     229980.233894
# 70          1  300367.437500     323149.386211
# 82          1  122736.742188      96058.098024
# 28          1  315150.500000     298969.196595
# 63          1  364217.593750     361290.005458

# %%
#1. En promedio, el modelo se equivoca en un 5.76% del precio real
#2. El modelo explica el 97.43% de la varianza del precio
#3. Error logaritmico (0.0807) es bajo; buen performance en escalas grandes.

#Conclusión: El modelo tiene muy buen ajuste global. Es explicativo (R2 alto) y preciso (MAPE pequeño)

# %%
#8. Guardar el modelo 
save_model(tuned_lr,'modelo_precio_final')
# Out:
# Transformation Pipeline and Model Successfully Saved
# (Pipeline(memory=Memory(location=None),
#           steps=[('numerical_imputer',
#                   TransformerWrapper(include=['area_m2', 'num_habitaciones',
#                                               'num_banos', 'antiguedad_anos',
#                                               'vista_mar'],
#                                      transformer=SimpleImputer())),
#                  ('categorical_imputer',
#                   TransformerWrapper(include=['distrito'],
#                                      transformer=SimpleImputer(strategy='most_frequent'))),
#                  ('onehot_encoding',
#                   TransformerWrapper(include=['distrito'],
#                                      transformer=OneHotEncoder(cols=['distrito'],
#                                                                handle_missing='return_nan',
#                                                                use_cat_names=True))),
#                  ('normalize', TransformerWrapper(transformer=StandardScaler())),
#                  ('trained_model', LinearRegression(n_jobs=-1))]),
#  'modelo_precio_final.pkl')
